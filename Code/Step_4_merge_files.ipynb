# %%
# libraries 
import pandas as pd 
import os
import numpy as np
import time
import random
from csv import reader
import time

# plots:
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


# scraping
from bs4 import BeautifulSoup
from lxml import etree #for using XPATH with beautifulsoup
import requests
import numpy as np

#JSON
import json

# GeoJSON
# import geopandas as gpd

# regular expression
import re 

# concurrent futures - boosts the process of scraping utilicing the CPU better
# two main classes- 
#       1) executor class: manages all the threads and workload
#       2) futures class: creates a little instance and manages data coming back
import concurrent.futures

# libraries: 
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

import glob

# %%
# path of the folder with all the csv files
input_folder = f'D:\Thesis\Properties\Denmark\RE_due_scraping_properties\Boliga_dk\Step_3_Scrape_The_properties'

# path of the outputfile - with all the tables merged
output = r'D:\Thesis\Properties\Denmark\RE_due_scraping_properties\Boliga_dk\Step_4_Merge_files\Boliga_merged_files.csv'

# collect all the csv files in the folder of the input_folder path
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

# the dataframe that will collect all tables
merged_data = pd.DataFrame()

counter = 0

for csv_file in csv_files:
    counter +=1
    
    print(f'########################## file nr. {counter} out of 104 ######################')
    print(csv_file)
    print('################################################################################')
    
    #get full path
    file_path = os.path.join(input_folder, csv_file)
    
    # read in the csv file
    df = pd.read_csv(file_path, encoding='utf-8', low_memory=False)
    
    print('************************************Data on csv file :**')
    
    # computing number of columns
    cols = len(df.axes[1])
    print(f'----------------- Number of columns csv file: {cols}')
    print()
    
    # computing number of rows
    rows = len(df.axes[0])
    print(f'----------------- Number of rows csv file: {rows}')
    
    # merge the df to the main dataframe
    merged_data = pd.concat([merged_data, df], ignore_index=True)
    
    print('***************************************Data on MAIN dataframe: **')
    # computing number of columns
    cols = len(merged_data.axes[1])
    print(f'----------------- Number of columns csv file: {cols}')
    print()
    
    # computing number of rows
    rows = len(merged_data.axes[0])
    print(f'----------------- Number of rows csv file: {rows}')
    print()

# Save the main dataframe
merged_data.to_csv(output, encoding="utf-8", index=False)
# Out:
# ########################## file nr. 1 out of 104 ######################
# Boliga_property_scrape_chunk_1.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
#
# ########################## file nr. 2 out of 104 ######################
# Boliga_property_scrape_chunk_2.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 20000
#
# ########################## file nr. 3 out of 104 ######################
# Boliga_property_scrape_chunk_3.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 30000
#
# ########################## file nr. 4 out of 104 ######################
# Boliga_property_scrape_chunk_4.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 40000
#
# ########################## file nr. 5 out of 104 ######################
# Boliga_property_scrape_chunk_5.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 50000
#
# ########################## file nr. 6 out of 104 ######################
# Boliga_property_scrape_chunk_6.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 60000
#
# ########################## file nr. 7 out of 104 ######################
# Boliga_property_scrape_chunk_7.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 70000
#
# ########################## file nr. 8 out of 104 ######################
# Boliga_property_scrape_chunk_8.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 80000
#
# ########################## file nr. 9 out of 104 ######################
# Boliga_property_scrape_chunk_9.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 90000
#
# ########################## file nr. 10 out of 104 ######################
# Boliga_property_scrape_chunk_10.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 100000
#
# ########################## file nr. 11 out of 104 ######################
# Boliga_property_scrape_chunk_11.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 110000
#
# ########################## file nr. 12 out of 104 ######################
# Boliga_property_scrape_chunk_12.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 120000
#
# ########################## file nr. 13 out of 104 ######################
# Boliga_property_scrape_chunk_13.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 130000
#
# ########################## file nr. 14 out of 104 ######################
# Boliga_property_scrape_chunk_14.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 140000
#
# ########################## file nr. 15 out of 104 ######################
# Boliga_property_scrape_chunk_15.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 150000
#
# ########################## file nr. 16 out of 104 ######################
# Boliga_property_scrape_chunk_16.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 160000
#
# ########################## file nr. 17 out of 104 ######################
# Boliga_property_scrape_chunk_17.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 170000
#
# ########################## file nr. 18 out of 104 ######################
# Boliga_property_scrape_chunk_18.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 180000
#
# ########################## file nr. 19 out of 104 ######################
# Boliga_property_scrape_chunk_19.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 190000
#
# ########################## file nr. 20 out of 104 ######################
# Boliga_property_scrape_chunk_20.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 200000
#
# ########################## file nr. 21 out of 104 ######################
# Boliga_property_scrape_chunk_21.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 210000
#
# ########################## file nr. 22 out of 104 ######################
# Boliga_property_scrape_chunk_22.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 220000
#
# ########################## file nr. 23 out of 104 ######################
# Boliga_property_scrape_chunk_23.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 230000
#
# ########################## file nr. 24 out of 104 ######################
# Boliga_property_scrape_chunk_24.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 240000
#
# ########################## file nr. 25 out of 104 ######################
# Boliga_property_scrape_chunk_25.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 250000
#
# ########################## file nr. 26 out of 104 ######################
# Boliga_property_scrape_chunk_26.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 260000
#
# ########################## file nr. 27 out of 104 ######################
# Boliga_property_scrape_chunk_27.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 270000
#
# ########################## file nr. 28 out of 104 ######################
# Boliga_property_scrape_chunk_28.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 280000
#
# ########################## file nr. 29 out of 104 ######################
# Boliga_property_scrape_chunk_29.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 290000
#
# ########################## file nr. 30 out of 104 ######################
# Boliga_property_scrape_chunk_30.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 300000
#
# ########################## file nr. 31 out of 104 ######################
# Boliga_property_scrape_chunk_31.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 310000
#
# ########################## file nr. 32 out of 104 ######################
# Boliga_property_scrape_chunk_32.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 320000
#
# ########################## file nr. 33 out of 104 ######################
# Boliga_property_scrape_chunk_33.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 330000
#
# ########################## file nr. 34 out of 104 ######################
# Boliga_property_scrape_chunk_34.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 340000
#
# ########################## file nr. 35 out of 104 ######################
# Boliga_property_scrape_chunk_35.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 350000
#
# ########################## file nr. 36 out of 104 ######################
# Boliga_property_scrape_chunk_36.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 360000
#
# ########################## file nr. 37 out of 104 ######################
# Boliga_property_scrape_chunk_37.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 370000
#
# ########################## file nr. 38 out of 104 ######################
# Boliga_property_scrape_chunk_38.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 380000
#
# ########################## file nr. 39 out of 104 ######################
# Boliga_property_scrape_chunk_39.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 390000
#
# ########################## file nr. 40 out of 104 ######################
# Boliga_property_scrape_chunk_40.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 400000
#
# ########################## file nr. 41 out of 104 ######################
# Boliga_property_scrape_chunk_41.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 410000
#
# ########################## file nr. 42 out of 104 ######################
# Boliga_property_scrape_chunk_42.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 420000
#
# ########################## file nr. 43 out of 104 ######################
# Boliga_property_scrape_chunk_43.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 430000
#
# ########################## file nr. 44 out of 104 ######################
# Boliga_property_scrape_chunk_44.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 440000
#
# ########################## file nr. 45 out of 104 ######################
# Boliga_property_scrape_chunk_45.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 450000
#
# ########################## file nr. 46 out of 104 ######################
# Boliga_property_scrape_chunk_46.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 460000
#
# ########################## file nr. 47 out of 104 ######################
# Boliga_property_scrape_chunk_47.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 470000
#
# ########################## file nr. 48 out of 104 ######################
# Boliga_property_scrape_chunk_48.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 480000
#
# ########################## file nr. 49 out of 104 ######################
# Boliga_property_scrape_chunk_49.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 490000
#
# ########################## file nr. 50 out of 104 ######################
# Boliga_property_scrape_chunk_50.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 500000
#
# ########################## file nr. 51 out of 104 ######################
# Boliga_property_scrape_chunk_51.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 510000
#
# ########################## file nr. 52 out of 104 ######################
# Boliga_property_scrape_chunk_52.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 520000
#
# ########################## file nr. 53 out of 104 ######################
# Boliga_property_scrape_chunk_53.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 530000
#
# ########################## file nr. 54 out of 104 ######################
# Boliga_property_scrape_chunk_54.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 540000
#
# ########################## file nr. 55 out of 104 ######################
# Boliga_property_scrape_chunk_55.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 550000
#
# ########################## file nr. 56 out of 104 ######################
# Boliga_property_scrape_chunk_56.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 560000
#
# ########################## file nr. 57 out of 104 ######################
# Boliga_property_scrape_chunk_57.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 570000
#
# ########################## file nr. 58 out of 104 ######################
# Boliga_property_scrape_chunk_58.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 580000
#
# ########################## file nr. 59 out of 104 ######################
# Boliga_property_scrape_chunk_59.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 590000
#
# ########################## file nr. 60 out of 104 ######################
# Boliga_property_scrape_chunk_60.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 600000
#
# ########################## file nr. 61 out of 104 ######################
# Boliga_property_scrape_chunk_61.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 610000
#
# ########################## file nr. 62 out of 104 ######################
# Boliga_property_scrape_chunk_62.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 620000
#
# ########################## file nr. 63 out of 104 ######################
# Boliga_property_scrape_chunk_63.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 630000
#
# ########################## file nr. 64 out of 104 ######################
# Boliga_property_scrape_chunk_64.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 640000
#
# ########################## file nr. 65 out of 104 ######################
# Boliga_property_scrape_chunk_65.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 650000
#
# ########################## file nr. 66 out of 104 ######################
# Boliga_property_scrape_chunk_66.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 660000
#
# ########################## file nr. 67 out of 104 ######################
# Boliga_property_scrape_chunk_67.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 670000
#
# ########################## file nr. 68 out of 104 ######################
# Boliga_property_scrape_chunk_68.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 680000
#
# ########################## file nr. 69 out of 104 ######################
# Boliga_property_scrape_chunk_69.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 690000
#
# ########################## file nr. 70 out of 104 ######################
# Boliga_property_scrape_chunk_70.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 700000
#
# ########################## file nr. 71 out of 104 ######################
# Boliga_property_scrape_chunk_71.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 710000
#
# ########################## file nr. 72 out of 104 ######################
# Boliga_property_scrape_chunk_72.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 720000
#
# ########################## file nr. 73 out of 104 ######################
# Boliga_property_scrape_chunk_73.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 730000
#
# ########################## file nr. 74 out of 104 ######################
# Boliga_property_scrape_chunk_74.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 740000
#
# ########################## file nr. 75 out of 104 ######################
# Boliga_property_scrape_chunk_75.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 750000
#
# ########################## file nr. 76 out of 104 ######################
# Boliga_property_scrape_chunk_76.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 760000
#
# ########################## file nr. 77 out of 104 ######################
# Boliga_property_scrape_chunk_77.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 770000
#
# ########################## file nr. 78 out of 104 ######################
# Boliga_property_scrape_chunk_78.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 780000
#
# ########################## file nr. 79 out of 104 ######################
# Boliga_property_scrape_chunk_79.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 790000
#
# ########################## file nr. 80 out of 104 ######################
# Boliga_property_scrape_chunk_80.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 800000
#
# ########################## file nr. 81 out of 104 ######################
# Boliga_property_scrape_chunk_81.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 810000
#
# ########################## file nr. 82 out of 104 ######################
# Boliga_property_scrape_chunk_82.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 820000
#
# ########################## file nr. 83 out of 104 ######################
# Boliga_property_scrape_chunk_83.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 830000
#
# ########################## file nr. 84 out of 104 ######################
# Boliga_property_scrape_chunk_84.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 840000
#
# ########################## file nr. 85 out of 104 ######################
# Boliga_property_scrape_chunk_85.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 850000
#
# ########################## file nr. 86 out of 104 ######################
# Boliga_property_scrape_chunk_86.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 9988
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 859988
#
# ########################## file nr. 87 out of 104 ######################
# Boliga_property_scrape_chunk_87.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 869988
#
# ########################## file nr. 88 out of 104 ######################
# Boliga_property_scrape_chunk_88.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 879988
#
# ########################## file nr. 89 out of 104 ######################
# Boliga_property_scrape_chunk_89.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 889988
#
# ########################## file nr. 90 out of 104 ######################
# Boliga_property_scrape_chunk_90.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 899988
#
# ########################## file nr. 91 out of 104 ######################
# Boliga_property_scrape_chunk_91.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 909988
#
# ########################## file nr. 92 out of 104 ######################
# Boliga_property_scrape_chunk_92.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 919988
#
# ########################## file nr. 93 out of 104 ######################
# Boliga_property_scrape_chunk_93.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 929988
#
# ########################## file nr. 94 out of 104 ######################
# Boliga_property_scrape_chunk_94.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 939988
#
# ########################## file nr. 95 out of 104 ######################
# Boliga_property_scrape_chunk_95.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 949988
#
# ########################## file nr. 96 out of 104 ######################
# Boliga_property_scrape_chunk_96.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 959988
#
# ########################## file nr. 97 out of 104 ######################
# Boliga_property_scrape_chunk_97.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 969988
#
# ########################## file nr. 98 out of 104 ######################
# Boliga_property_scrape_chunk_98.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 979988
#
# ########################## file nr. 99 out of 104 ######################
# Boliga_property_scrape_chunk_99.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 989988
#
# ########################## file nr. 100 out of 104 ######################
# Boliga_property_scrape_chunk_100.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 999988
#
# ########################## file nr. 101 out of 104 ######################
# Boliga_property_scrape_chunk_101.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 1009988
#
# ########################## file nr. 102 out of 104 ######################
# Boliga_property_scrape_chunk_102.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 1019988
#
# ########################## file nr. 103 out of 104 ######################
# Boliga_property_scrape_chunk_103.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 10000
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 1029988
#
# ########################## file nr. 104 out of 104 ######################
# Boliga_property_scrape_chunk_104.csv
# ################################################################################
# ************************************Data on csv file :**
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 1607
# ***************************************Data on MAIN dataframe: **
# ----------------- Number of columns csv file: 48
#
# ----------------- Number of rows csv file: 1031595

# %%
len(merged_data)
# Out:
# 1031595
